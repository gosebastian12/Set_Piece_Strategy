# %% [markdown]
# # Neccessary Import Statements

# %%
# Allows for changes made to scripts in src to be included in the work
# done in this notebook.
# %load_ext autoreload
# %autoreload 2

# %%
# Data Manipulation
import pandas as pd

# Custom Modules
from src.data import data_loader
from src.data import set_piece_extractor as spe

# %% [markdown]
# # Load in Full Original Data

# %%
full_df = data_loader.raw_event_data("all")
full_df.head(n=15)
# Out:
#     eventId            subEventName                         tags  playerId  \
# 0         8             Simple pass               [{'id': 1801}]    253784
# 1         8               High pass               [{'id': 1801}]     29474
# 2         1                Air duel  [{'id': 703}, {'id': 1801}]    253784
# 3         1                Air duel  [{'id': 701}, {'id': 1802}]     56441
# 4         1   Ground attacking duel  [{'id': 702}, {'id': 1801}]    366760
# 5         1   Ground defending duel  [{'id': 702}, {'id': 1801}]     28529
# 6         1  Ground loose ball duel  [{'id': 701}, {'id': 1802}]    366760
# 7         1  Ground loose ball duel  [{'id': 703}, {'id': 1801}]     56441
# 8         7                   Touch                           []     26389
# 9         7                   Touch               [{'id': 1401}]     26265
# 10        8             Simple pass               [{'id': 1801}]     56441
# 11        7               Clearance               [{'id': 1802}]     26389
# 12        8               Hand pass               [{'id': 1801}]     26245
# 13        8             Simple pass               [{'id': 1801}]     26086
# 14        8             Simple pass               [{'id': 1801}]     29474
#
#                                    positions  matchId           eventName  \
# 0   [{'y': 51, 'x': 50}, {'y': 46, 'x': 31}]  2500686                Pass
# 1   [{'y': 46, 'x': 31}, {'y': 74, 'x': 68}]  2500686                Pass
# 2   [{'y': 74, 'x': 68}, {'y': 54, 'x': 72}]  2500686                Duel
# 3   [{'y': 26, 'x': 32}, {'y': 46, 'x': 28}]  2500686                Duel
# 4   [{'y': 54, 'x': 72}, {'y': 55, 'x': 73}]  2500686                Duel
# 5   [{'y': 46, 'x': 28}, {'y': 45, 'x': 27}]  2500686                Duel
# 6   [{'y': 55, 'x': 73}, {'y': 62, 'x': 70}]  2500686                Duel
# 7   [{'y': 45, 'x': 27}, {'y': 38, 'x': 30}]  2500686                Duel
# 8   [{'y': 38, 'x': 30}, {'y': 40, 'x': 27}]  2500686  Others on the ball
# 9   [{'y': 80, 'x': 67}, {'y': 60, 'x': 73}]  2500686  Others on the ball
# 10  [{'y': 40, 'x': 27}, {'y': 40, 'x': 34}]  2500686                Pass
# 11  [{'y': 40, 'x': 34}, {'y': 54, 'x': 87}]  2500686  Others on the ball
# 12  [{'y': 46, 'x': 13}, {'y': 86, 'x': 34}]  2500686                Pass
# 13  [{'y': 86, 'x': 34}, {'y': 39, 'x': 32}]  2500686                Pass
# 14  [{'y': 39, 'x': 32}, {'y': 78, 'x': 32}]  2500686                Pass
#
#     teamId matchPeriod   eventSec subEventId         id
# 0     3799          1H   1.935181         85  176505119
# 1     3799          1H   3.599295         83  176505121
# 2     3799          1H   6.827043         10  176505122
# 3     3772          1H   6.985577         10  176505017
# 4     3799          1H   9.511272         11  176505124
# 5     3772          1H  10.041222         12  176505018
# 6     3799          1H  10.499829         13  176505127
# 7     3772          1H  11.074277         13  176505019
# 8     3772          1H  12.260977         72  176505020
# 9     3799          1H  13.344344         72  176505132
# 10    3772          1H  13.710413         85  176505021
# 11    3772          1H  15.158430         71  176505022
# 12    3799          1H  19.984771         81  176505135
# 13    3799          1H  26.513924         85  176505137
# 14    3799          1H  30.569943         85  176505138

# %% [markdown]
# Evidently, we have north of 3 million total events in our data set!

# %% [markdown]
# # Extract Out All Set Piece Events

# %% [markdown]
# To help us do this, we can load in the CSV file that describes the mapping between event IDs and the types of events.

# %%
event_ID_mapper = data_loader.event_id_mapper()
event_ID_mapper
# Out:
#     event  subevent              event_label           subevent_label
# 0       1        10                     Duel                 Air duel
# 1       1        11                     Duel    Ground attacking duel
# 2       1        12                     Duel    Ground defending duel
# 3       1        13                     Duel   Ground loose ball duel
# 4       2        20                     Foul                     Foul
# 5       2        21                     Foul                Hand foul
# 6       2        22                     Foul           Late card foul
# 7       2        23                     Foul         Out of game foul
# 8       2        24                     Foul                  Protest
# 9       2        25                     Foul               Simulation
# 10      2        26                     Foul           Time lost foul
# 11      2        27                     Foul             Violent Foul
# 12      3        30                Free Kick                   Corner
# 13      3        31                Free Kick                Free Kick
# 14      3        32                Free Kick          Free kick cross
# 15      3        33                Free Kick           Free kick shot
# 16      3        34                Free Kick                Goal kick
# 17      3        35                Free Kick                  Penalty
# 18      3        36                Free Kick                 Throw in
# 19      4        40  Goalkeeper leaving line  Goalkeeper leaving line
# 20      5        50             Interruption    Ball out of the field
# 21      5        51             Interruption                  Whistle
# 22      6        60                  Offside                  Offside
# 23      7        70       Others on the ball             Acceleration
# 24      7        71       Others on the ball                Clearance
# 25      7        72       Others on the ball                    Touch
# 26      8        80                     Pass                    Cross
# 27      8        81                     Pass                Hand pass
# 28      8        82                     Pass                Head pass
# 29      8        83                     Pass                High pass
# 30      8        84                     Pass                   Launch
# 31      8        85                     Pass              Simple pass
# 32      8        86                     Pass               Smart pass
# 33      9        90             Save attempt                 Reflexes
# 34      9        91             Save attempt             Save attempt
# 35     10       100                     Shot                     Shot

# %% [markdown]
# Investigating this DataFrame, we notice that all of the set pieces (which includes free kicks, corners, goal kicks, penalties, and throw in's) all fall under the `event` ID 3. Thus, to extract all of the set piece events, a good place to start is to take all of the events who's type has been classified with `event` ID 3. This is why we extract out all of the row instances where its `event` entry is 3 in the `set_piece_initating_events_extractor` function that can be found in the `src/data/set_piece_extractor` module.

# %%
sp_beginning_ids = spe.set_piece_initating_events_extractor()
print(len(sp_beginning_ids))
# Out:
# 181171

# %% [markdown]
# Evidently, we have 181171 set pieces that we will have to accumulate sequences for!

# %%
sp_sequences_df = spe.set_piece_sequences_compiler()
sp_sequences_df.head(n=15)
# Out:
# While running all of the tests to figure out when and     	where the set piece sequence of interest ended, it was determined     	that none of those tests passed. The ID for the event that started     	this set piece sequence is `176506366`.
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-3-80e2f8eb9484> in <module>
# ----> 1 sp_sequences_df = spe.set_piece_sequences_compiler()
#       2 sp_sequences_df.head(n=15)
#
# ~/Documents/Professional_Development/Sharpest_Minds/Set_Piece_Strategy_Identifier/src/data/set_piece_extractor.py in set_piece_sequences_compiler(initiating_events)
#     350 	sequences_dfs_list = [
#     351                 set_piece_sequence_generator(event_id) \
# --> 352                 for event_id in initiating_event_ids
#     353 	]
#     354
#
# ~/Documents/Professional_Development/Sharpest_Minds/Set_Piece_Strategy_Identifier/src/data/set_piece_extractor.py in <listcomp>(.0)
#     350 	sequences_dfs_list = [
#     351                 set_piece_sequence_generator(event_id) \
# --> 352                 for event_id in initiating_event_ids
#     353 	]
#     354
#
# ~/Documents/Professional_Development/Sharpest_Minds/Set_Piece_Strategy_Identifier/src/data/set_piece_extractor.py in set_piece_sequence_generator(set_piece_start_id)
#     282
#     283         print(err_msg)
# --> 284         raise ass_err
#     285
#     286     which_test_passed = np.argwhere(results_list).flatten()[0]
#
# ~/Documents/Professional_Development/Sharpest_Minds/Set_Piece_Strategy_Identifier/src/data/set_piece_extractor.py in set_piece_sequence_generator(set_piece_start_id)
#     273     try:
#     274         # It must be true that at least one of the test returned true.
# --> 275         assert any(results_list)
#     276     except AssertionError as ass_err:
#     277         # If none of the test passed, we must let the user know.
#
# AssertionError:

# %%
spe.set_piece_sequence_generator(176506366)
# Out:
#     eventId             subEventName  \
# 0         3                 Throw in
# 1         8              Simple pass
# 2         8                    Cross
# 3         7                Clearance
# 4         8              Simple pass
# 5         1    Ground defending duel
# 6         1    Ground attacking duel
# 7         1    Ground defending duel
# 8         1    Ground attacking duel
# 9         8              Simple pass
# 10        8              Simple pass
# 11        8              Simple pass
# 12        8                High pass
# 13        4  Goalkeeper leaving line
# 14        1                 Air duel
# 15        8              Simple pass
# 16        7                    Touch
# 17        1   Ground loose ball duel
# 18        1   Ground loose ball duel
# 19        8               Smart pass
# 20       10                     Shot
# 21        9                 Reflexes
# 22        7                Clearance
# 23        8              Simple pass
# 24        8              Simple pass
# 25        8              Simple pass
#
#                                                  tags  playerId  \
# 0                                      [{'id': 1801}]     27958
# 1                                      [{'id': 1801}]    334552
# 2            [{'id': 401}, {'id': 801}, {'id': 1802}]     27958
# 3                        [{'id': 1401}, {'id': 1802}]     27646
# 4                                      [{'id': 1801}]     56441
# 5            [{'id': 504}, {'id': 701}, {'id': 1802}]     26638
# 6            [{'id': 503}, {'id': 703}, {'id': 1801}]     28529
# 7            [{'id': 503}, {'id': 701}, {'id': 1802}]     26120
# 8            [{'id': 504}, {'id': 703}, {'id': 1801}]     28529
# 9                                      [{'id': 1801}]     28529
# 10                                     [{'id': 1801}]    300485
# 11                                     [{'id': 1801}]     56441
# 12                        [{'id': 901}, {'id': 1802}]     27958
# 13                                                 []     26245
# 14                        [{'id': 701}, {'id': 1802}]    274970
# 15                                     [{'id': 1801}]     26245
# 16                                                 []    274344
# 17                        [{'id': 701}, {'id': 1802}]    274344
# 18                        [{'id': 703}, {'id': 1801}]     26389
# 19           [{'id': 302}, {'id': 901}, {'id': 1801}]    274970
# 20  [{'id': 402}, {'id': 201}, {'id': 1201}, {'id'...    334552
# 21                       [{'id': 1201}, {'id': 1801}]     26245
# 22                       [{'id': 1401}, {'id': 1801}]     26086
# 23                                     [{'id': 1802}]     26265
# 24                                     [{'id': 1801}]     25596
# 25                                     [{'id': 1801}]      3573
#
#                                      positions  matchId  \
# 0       [{'y': 0, 'x': 77}, {'y': 7, 'x': 92}]  2500686
# 1      [{'y': 7, 'x': 92}, {'y': 12, 'x': 84}]  2500686
# 2     [{'y': 12, 'x': 84}, {'y': 56, 'x': 94}]  2500686
# 3      [{'y': 44, 'x': 6}, {'y': 57, 'x': 31}]  2500686
# 4     [{'y': 43, 'x': 69}, {'y': 82, 'x': 63}]  2500686
# 5     [{'y': 18, 'x': 37}, {'y': 31, 'x': 32}]  2500686
# 6     [{'y': 82, 'x': 63}, {'y': 69, 'x': 68}]  2500686
# 7     [{'y': 31, 'x': 32}, {'y': 31, 'x': 29}]  2500686
# 8     [{'y': 69, 'x': 68}, {'y': 69, 'x': 71}]  2500686
# 9     [{'y': 69, 'x': 71}, {'y': 95, 'x': 83}]  2500686
# 10    [{'y': 95, 'x': 83}, {'y': 52, 'x': 67}]  2500686
# 11    [{'y': 52, 'x': 67}, {'y': 23, 'x': 64}]  2500686
# 12  [{'y': 23, 'x': 64}, {'y': 100, 'x': 100}]  2500686
# 13      [{'y': 0, 'x': 0}, {'y': 77, 'x': 36}]  2500686
# 14    [{'y': 59, 'x': 90}, {'y': 58, 'x': 86}]  2500686
# 15    [{'y': 42, 'x': 14}, {'y': 53, 'x': 23}]  2500686
# 16    [{'y': 53, 'x': 23}, {'y': 52, 'x': 25}]  2500686
# 17    [{'y': 52, 'x': 25}, {'y': 34, 'x': 23}]  2500686
# 18    [{'y': 48, 'x': 75}, {'y': 66, 'x': 77}]  2500686
# 19    [{'y': 66, 'x': 77}, {'y': 37, 'x': 88}]  2500686
# 20  [{'y': 37, 'x': 88}, {'y': 100, 'x': 100}]  2500686
# 21      [{'y': 0, 'x': 0}, {'y': 63, 'x': 12}]  2500686
# 22     [{'y': 49, 'x': 3}, {'y': 96, 'x': 26}]  2500686
# 23    [{'y': 96, 'x': 26}, {'y': 67, 'x': 45}]  2500686
# 24    [{'y': 33, 'x': 55}, {'y': 53, 'x': 42}]  2500686
# 25    [{'y': 53, 'x': 42}, {'y': 79, 'x': 38}]  2500686
#
#                   eventName  teamId matchPeriod     eventSec subEventId  \
# 0                 Free Kick    3772          2H  1531.244420         36
# 1                      Pass    3772          2H  1532.609477         85
# 2                      Pass    3772          2H  1534.154528         80
# 3        Others on the ball    3799          2H  1535.515472         71
# 4                      Pass    3772          2H  1538.580060         85
# 5                      Duel    3799          2H  1540.308386         12
# 6                      Duel    3772          2H  1541.002092         11
# 7                      Duel    3799          2H  1542.116169         12
# 8                      Duel    3772          2H  1542.738620         11
# 9                      Pass    3772          2H  1544.356690         85
# 10                     Pass    3772          2H  1548.307431         85
# 11                     Pass    3772          2H  1551.783422         85
# 12                     Pass    3772          2H  1554.368759         83
# 13  Goalkeeper leaving line    3799          2H  1556.845893         40
# 14                     Duel    3772          2H  1557.497123         10
# 15                     Pass    3799          2H  1569.501484         85
# 16       Others on the ball    3799          2H  1570.313995         72
# 17                     Duel    3799          2H  1571.681099         13
# 18                     Duel    3772          2H  1571.824987         13
# 19                     Pass    3772          2H  1574.725544         86
# 20                     Shot    3772          2H  1576.405874        100
# 21             Save attempt    3799          2H  1576.599937         90
# 22       Others on the ball    3799          2H  1578.414330         71
# 23                     Pass    3799          2H  1584.440463         85
# 24                     Pass    3772          2H  1587.292825         85
# 25                     Pass    3772          2H  1591.088558         85
#
#            id
# 0   176506366
# 1   176506367
# 2   176506368
# 3   176506452
# 4   176506369
# 5   176506454
# 6   176506370
# 7   176506456
# 8   176506371
# 9   176506372
# 10  176506373
# 11  176506374
# 12  176506375
# 13  176506458
# 14  176506376
# 15  176506460
# 16  176506464
# 17  176506465
# 18  176506377
# 19  176506379
# 20  176506380
# 21  176506468
# 22  176506471
# 23  176506472
# 24  176506381
# 25  176506382
